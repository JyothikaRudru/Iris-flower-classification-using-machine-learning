# %% [markdown]
# ### Iris flower classification project

# %% [markdown]
# ##### Steps
# ###### Load the data
# ###### Analyze and visualize the dataset
# ###### Model Training
# ###### Model evaluation
# ###### Testing the model

# %%
#import necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load iris dataset
data=sns.load_dataset('iris')
df=pd.DataFrame(data,columns=['sepal_length','sepal_width','petal_length','petal_width','class_labels'])
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class_labels
# 0             5.1          3.5           1.4          0.2           NaN
# 1             4.9          3.0           1.4          0.2           NaN
# 2             4.7          3.2           1.3          0.2           NaN
# 3             4.6          3.1           1.5          0.2           NaN
# 4             5.0          3.6           1.4          0.2           NaN
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3           NaN
# 146           6.3          2.5           5.0          1.9           NaN
# 147           6.5          3.0           5.2          2.0           NaN
# 148           6.2          3.4           5.4          2.3           NaN
# 149           5.9          3.0           5.1          1.8           NaN
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Statistical analysis
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#visualize the whole dataset
sns.pairplot(data,hue='species',palette=['#4B0082', '#6A5ACD', '#8A2BE2'])

# %% [markdown]
# from this visualization, we can tell that iris-setosa is well separated from the other two flowers and iris virginica is the longest flower and iris setosa is the shortest flower

# %% [markdown]
# #### Separating the input columns and the output columns

# %%
#separate the features and target
data1=data.values
x=data1[:,0:4]
y=data1[:,4]

# %% [markdown]
# #### Spliting the data into training and testing

# %%
# Split the data to train and test dataset.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# #### Support Vector Machine

# %%
# Support vector machine algorithm
from sklearn.svm import SVC
svn = SVC()
svn.fit(X_train, y_train)
# Out:
# SVC()

# %%
# Predict from the test dataset
prediction = svn.predict(X_test)
# Calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction)*100)
for i in range(len(prediction)):
    print('Test:',y_test[i],'\t''Prediction:',prediction[i])
# Out:
# 96.66666666666667
# Test: setosa 	Prediction: setosa
# Test: setosa 	Prediction: setosa
# Test: virginica 	Prediction: virginica
# Test: setosa 	Prediction: setosa
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: setosa 	Prediction: setosa
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: setosa 	Prediction: setosa
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: virginica 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: setosa 	Prediction: setosa
# Test: setosa 	Prediction: setosa
# Test: versicolor 	Prediction: versicolor
# ...

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predict from the test dataset
prediction1 = LR.predict(X_test)
# Calculate the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction1)*100)
for i in range(len(prediction1)):
    print('Test:',y_test[i],'\t''Prediction:',prediction1[i])
# Out:
# 100.0
# Test: setosa 	Prediction: setosa
# Test: setosa 	Prediction: setosa
# Test: virginica 	Prediction: virginica
# Test: setosa 	Prediction: setosa
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: setosa 	Prediction: setosa
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: setosa 	Prediction: setosa
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: versicolor 	Prediction: versicolor
# Test: virginica 	Prediction: virginica
# Test: versicolor 	Prediction: versicolor
# Test: setosa 	Prediction: setosa
# Test: setosa 	Prediction: setosa
# Test: versicolor 	Prediction: versicolor
# ...

# %% [markdown]
# #### Prediction of the new input

# %%
X_new = np.array([[2.9,1,3,0.4], [1.6,3,2,2.2 ], [1,0.4,2,1.9]])
#Prediction of the species from the input vector
prediction = svn.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['versicolor' 'setosa' 'setosa']
